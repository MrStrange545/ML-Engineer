# %% [markdown]
# **Resources**
# - Data Science handbook

# %% [markdown]
# # Introduction

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib Styles

# %% [markdown]
# ### Checking available styles

# %%
# List all available styles
styles = plt.style.available

# print all available styles
styles
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### Setting Styles

# %%
plt.style.use('classic')

# %% [markdown]
# ### Usage os `show()`

# %% [markdown]
# `plt.show()` must be used only once in the end of the script.
# In Jupyter notebook, it is not mandatory

# %%
x = np.linspace(0,10,100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-') # Plane line
plt.plot(x, np.cos(x),  '--') # Dotted line

plt.show()

# %% [markdown]
# ### Saving figures to file

# %%
fig.savefig('Attachments/my_figure.png')

# fig is the figure object created last in the above code cell.
# This png file will be saved to Attachments folder in cwd

# %% [markdown]
# To check the image, see the follwing code cell

# %%
from IPython.display import Image
Image('Attachments/my_figure.png')

# %% [markdown]
# To check what are the supported file extension for exporting an image:

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ## Two interfaces for the price of One
# 1. MATLAB-style interface
# 2. OOP interface (recommended)

# %% [markdown]
# ### 1. MATLAB interface

# %%
plt.figure() # create a plot figure

plt.subplot(2,1,1) # (rows, column, panel number)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2) # second panel
plt.plot(x,np.cos(x))

plt.show()

# %% [markdown]
# ### Object-Oriented Interface

# %%
# First create a grid of plots
# ax will be an array of two axes objects
fig, ax = plt.subplots(2)

# call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

plt.show()

# %% [markdown]
# # Simple Line Plots

# %% [markdown]
# For all matplotlib plots, we start by creating a figure and an axes

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# **Toggle grid on/off**

# %%
plt.grid(True)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# ## Adjusting the Plot: Line colors and Styles

# %% [markdown]
# ### Line color
# - `color` or `c` parameter

# %%
plt.plot(x, np.sin(x-0), c='blue')        # specify color by name
plt.plot(x, np.sin(x-1), c='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x-2), c='0.75')        # Grayscale btw 0 & 1
plt.plot(x, np.sin(x-3), c='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x-4), c=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x-5), c='chartreuse')  # all html color names supported

plt.show()

# %% [markdown]
# ### Line Style
# - `ls` or `linestyle` parameter

# %%
plt.plot(x, x+0, ls='solid')
plt.plot(x, x+1, ls='dashed')
plt.plot(x, x+2, ls='dashdot')
plt.plot(x, x+3, ls='dotted')

# For short, you can use the following codes:
plt.plot(x, np.sin(x+4), ls='-')  # solid
plt.plot(x, np.sin(x+5), ls='--') # dashed
plt.plot(x, np.sin(x+6), ls='-.') # dashdot
plt.plot(x, np.sin(x+7), ls=':')  # dotted

plt.show()

# %% [markdown]
# these both parameters can be combined

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %%
## Adjusting the plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5,1.5)

plt.show()

# %% [markdown]
# If for some reason you'd like either axis to be displayed in reverse, you can simply reverse the order of the arguments:

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is `plt.axis()`. This method allows you to limit the both axis in single call.
#
# we have to pass a list as a argument `[xmin,xmax,ymin,max]`:

# %%
plt.plot(x, np.sin(x))

plt.axis([-1,11,-1.5,1.5])
plt.show()

# %% [markdown]
# The ``plt.axis()`` method goes even beyond this, allowing you to do things like automatically tighten the bounds around the current plot:

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')

plt.show()

# %% [markdown]
# It allows even higher-level specifications, such as ensuring an equal aspect ratio so that on your screen, one unit in ``x`` is equal to one unit in ``y``:

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# ## Labeling Plots

# %%
plt.plot(x, np.sin(x))

plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")

plt.show()

# %% [markdown]
# ### Legend

# %%
plt.plot(x, np.sin(x), '-g', label="sin(x)")
plt.plot(x, np.cos(x), ':b', label="cos(x)")

plt.axis('equal')
plt.legend()

plt.show()

# %% [markdown]
# ## Aside: Matplotlib Gotchas
#
# While most ``plt`` functions translate directly to ``ax`` methods (such as ``plt.plot()`` → ``ax.plot()``, ``plt.legend()`` → ``ax.legend()``, etc.), this is not the case for all commands.
# In particular, functions to set limits, labels, and titles are slightly modified.
# For transitioning between MATLAB-style functions and object-oriented methods, make the following changes:
#
# - ``plt.xlabel()``  → ``ax.set_xlabel()``
# - ``plt.ylabel()`` → ``ax.set_ylabel()``
# - ``plt.xlim()``  → ``ax.set_xlim()``
# - ``plt.ylim()`` → ``ax.set_ylim()``
# - ``plt.title()`` → ``ax.set_title()``
#
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ``ax.set()`` method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# # Scatter plots

# %% [markdown]
# ## Scatter plot with `plt.plot()`

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

plt.plot(x,y,'o',c='k')
plt.axis('equal')
plt.show()

# %% [markdown]
# There are many markers available.
#
# For more possibilities, you can combine marker with color codes and line

# %%
plt.plot(x,y, '-ok')

plt.show()

# %% [markdown]
# Additional keyword arguments to ``plt.plot`` specify a wide range of properties of the lines and markers:

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ## Scatter plot with plt.scatter

# %%
plt.scatter(x,y, marker='o')

plt.show()

# %% [markdown]
# The primary difference of ``plt.scatter`` from ``plt.plot`` is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.

# %%
rng = np.random.RandomState(42)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x,y, c=colors, s=sizes, alpha=0.3, cmap='viridis')

plt.colorbar() # show color scale

plt.show()

# %% [markdown]
# Let's see another example, here we will plot the iris data

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')

plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])

plt.show()

# %% [markdown]
# ## `plot` versus `scatter`: A note on Efficiency
# - plt.plot should be preferred over plt.scatter for large datasets

# %% [markdown]
# # Visualizing errors

# %% [markdown]
# ## Basic Errorbars

# %%
x = np.linspace(0,10,50)
dy = 0.3
y = np.sin(x)+ dy * np.random.randn(50)

plt.errorbar(x,y, yerr=dy, fmt='.k')

plt.show()

# %% [markdown]
# Here, fmt is (format code controlling the appearance of lines and points, and has the same syntax as the shorthand used in `plt.plot`.
#
# Additional functionality

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0)

plt.show()

# %% [markdown]
# ## Continuous Errors
# No direct method, but can be accomplished by `plt.plot` and `plt.fill_between`.
